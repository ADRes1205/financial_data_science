# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn import metrics

# %%
# Load the credit card dataset
CC = pd.read_csv('CCsmall.csv')
CC
# Out:
#                V1         V2  Class
# 0       -1.359807  -0.072781      0
# 1        1.191857   0.266151      0
# 2       -1.358354  -1.340163      0
# 3       -0.966272  -0.185226      0
# 4       -1.158233   0.877737      0
# ...           ...        ...    ...
# 284802 -11.881118  10.071785      0
# 284803  -0.732789  -0.055080      0
# 284804   1.919565  -0.301254      0
# 284805  -0.240440   0.530483      0
# 284806  -0.533413  -0.189733      0
#
# [284807 rows x 3 columns]

# %%
# Define input and output features
X = CC[['V1','V2']]
y = CC[['Class']]

# Scatterplot of the credit card data
p = sns.scatterplot(data=CC, x='V1', y='V2',
                    hue='Class', style='Class', markers=['s', '^'])
p.set_xlabel('V1', fontsize=14);
p.set_ylabel('V2', fontsize=14);

# %%
# Initialize a model with k=5 neighbors
knn = KNeighborsClassifier(n_neighbors=5)

# Fit the model
knn.fit(X, np.ravel(y))

# Calculate the predictions for each instance in X
knnypred = knn.predict(X)

# Display the confusion matrix
metrics.confusion_matrix(np.ravel(y), knnypred)
# Out:
# array([[284292,     23],
#        [   375,    117]])

# %%
# Initialize a logistic regression model
lrm = LogisticRegression(penalty=None)

# Fit the model
lrm.fit(X, np.ravel(y))

# Calculate the predictions for each instance in X
lrmypred=lrm.predict(X)

# Display the confusion matrix
metrics.confusion_matrix(np.ravel(y), lrmypred)
# Out:
# array([[284303,     12],
#        [   450,     42]])

# %%
# Initialize a Gaussian naive Bayes model
GNBm = GaussianNB()

# Fit the model
GNBm.fit(X,np.ravel(y))

# Calculate the predictions for each instance in X
GNBmypred=GNBm.predict(X)

# Display the confusion matrix
metrics.confusion_matrix(np.ravel(y), GNBmypred)
# Out:
# array([[280734,   3581],
#        [   361,    131]])
